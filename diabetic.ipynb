# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhisekdassleek/abhisekdas/blob/main/diabetic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('Final_health_data.csv')
df.head()
# Out:
#   Native_community  gender      age         medical_specialty  \
# 0        Caucasian  Female   [0-10)  Pediatrics-Endocrinology
# 1        Caucasian  Female  [10-20)                         ?
# 2  AfricanAmerican  Female  [20-30)                         ?
# 3        Caucasian    Male  [30-40)                         ?
# 4        Caucasian    Male  [40-50)                         ?
#
#    num_medications  number_diagnoses insulin change readmitted
# 0                0                 1      No     No         NO
# 1                0                 9      Up     Ch        >30
# 2                5                 6      No     No         NO
# 3                1                 7      Up     Ch         NO
# 4                0                 5  Steady     Ch         NO

# %%
df.describe()
# Out:
#        num_medications  number_diagnoses
# count    101766.000000     101766.000000
# mean          1.339730          7.422607
# std           1.705807          1.933600
# min           0.000000          1.000000
# 25%           0.000000          6.000000
# 50%           1.000000          8.000000
# 75%           2.000000          9.000000
# max           6.000000         16.000000

# %%
def value_plot(df, y, sort_ascending=False, figscale=1):
  figsize = (7 * figscale, 4 * figscale)
  if sort_ascending:
    df = df.sort_values(y).reset_index(drop=True)
  _, ax = plt.subplots(figsize=figsize)
  df[y].plot(kind='line')
  plt.title(y)
  ax.spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
chart = value_plot(_df_9, *['number_diagnoses'], **{})
chart

# %%
def histogram(df, colname, num_bins=20, figscale=1):
  figsize = (8 * figscale, 4 * figscale)
  _, ax = plt.subplots(figsize=figsize)
  plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
  plt.ylabel('count')
  plt.title(colname)
  ax.spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
chart = histogram(_df_2, *['num_medications'], **{})
chart

# %%
plt.bar(df['gender'], df['age'])
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Age', fontsize=14)
plt.title('Age Distribution by Gender', fontsize=16)
plt.show()

# %%
plt.bar(df['readmitted'], df['age'])
plt.xlabel('readmitted', fontsize=14)
plt.ylabel('age', fontsize=14)
plt.title(' age distribution by re-admission ', fontsize=16)
plt.show()

# %%
plt.bar(df['insulin'], df['readmitted'])
plt.xlabel('insulin', fontsize=14)
plt.ylabel('readmitted', fontsize=14)
plt.title('Age Distribution by Gender', fontsize=16)
plt.show()

# %%
sns.pairplot(df, hue='readmitted')
